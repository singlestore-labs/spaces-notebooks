# %% [markdown]
# <div id="singlestore-header" style="display: flex; background-color: rgba(235, 249, 245, 0.25); padding: 5px;">
#     <div id="icon-image" style="width: 90px; height: 90px;">
#         <img width="100%" height="100%" src="https://raw.githubusercontent.com/singlestore-labs/spaces-notebooks/master/common/images/header-icons/browser.png" />
#     </div>
#     <div id="text" style="padding: 5px; margin-left: 10px;">
#         <div id="badge" style="display: inline-block; background-color: rgba(0, 0, 0, 0.15); border-radius: 4px; padding: 4px 8px; align-items: center; margin-top: 6px; margin-bottom: -2px; font-size: 80%">SingleStore Notebooks</div>
#         <h1 style="font-weight: 500; margin: 8px 0 0 4px;">Run your first Python UDF</h1>
#     </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b class="fa fa-solid fa-exclamation-circle"></b>
#     <div>
#         <p><b>Note</b></p>
#         <p>This notebook can be run on a Free Starter Workspace. To create a Free Starter Workspace navigate to <tt>Start</tt> using the left nav. You can also use your existing Standard or Premium workspace with this Notebook.</p>
#     </div>
# </div>

# %% [markdown]
# ## Create some simple tables
#
# This setup establishes a basic relational structure to store some reviews for restaurants. Ensure you have selected a database.

# %%
# %%sql
# DROP TABLE IF EXISTS items;
#
# CREATE TABLE IF NOT EXISTS
# items (
#     id INT PRIMARY KEY,
#     name VARCHAR(255) NOT NULL,
#     price INT NOT NULL,
#     quantity INT NOT NULL
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## Insert sample data

# %%
# %%sql INSERT into items (id, name, price, quantity) values
# ("1", "Pasta",4, 10 ),
# ("2", "Guanciale",2, 5 ),
# ("3", "Eggs",1, 3 ),
# ("4", "Cheese",5, 6 ),
# ("5", "Black Pepper",1, 5 );
# Out:
# 5 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## Define Python UDF functions
#
# Next, we will be Python UDF function using the `@udf` annotation.

# %%
from singlestoredb.functions import udf

@udf
def x_multiply(a: int,b: int) -> int:
    return a*b

# %% [markdown]
# ## Start the Python UDF server
#
# This will start the server as well as register all the functions annotated with `@udf` as external user defined functions on your selected database.

# %%
import singlestoredb.apps as apps
connection_info = await apps.run_udf_app()
# Out:
# Python UDF registered at https://apps.us-east-1.cloud.singlestore.com/pythonudfs/727f6ac9-17a8-42f3-857b-67186c46bbbd/interactive/

# %% [markdown]
# ## Publish Python UDF
#
# After optionally validating the Python UDF interactively, you can publish it and access it like
#
# ```sql
# SELECT id, name, price, quantity, x_multiply(price, quantity) as total_value from items order by id;
# ```
#
# enriching your data exploration experience seamlessly!

# %% [markdown]
# <div id="singlestore-footer" style="background-color: rgba(194, 193, 199, 0.25); height:2px; margin-bottom:10px"></div>
# <div><img src="https://raw.githubusercontent.com/singlestore-labs/spaces-notebooks/master/common/images/singlestore-logo-grey.png" style="padding: 0px; margin: 0px; height: 24px"/></div>
