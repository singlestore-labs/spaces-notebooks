# %% [markdown]
# <div id="singlestore-header" style="display: flex; background-color: rgba(255, 182, 176, 0.25); padding: 5px;">
#     <div id="icon-image" style="width: 90px; height: 90px;">
#         <img width="100%" height="100%" src="https://raw.githubusercontent.com/singlestore-labs/spaces-notebooks/master/common/images/header-icons/radar.png" />
#     </div>
#     <div id="text" style="padding: 5px; margin-left: 10px;">
#         <div id="badge" style="display: inline-block; background-color: rgba(0, 0, 0, 0.15); border-radius: 4px; padding: 4px 8px; align-items: center; margin-top: 6px; margin-bottom: -2px; font-size: 80%">SingleStore Notebooks</div>
#         <h1 style="font-weight: 500; margin: 8px 0 0 4px;">SingleStore Fundamentals</h1>
#     </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b class="fa fa-solid fa-exclamation-circle"></b>
#     <div>
#         <p><b>Note</b></p>
#         <p>This notebook can be run on a Free Starter Workspace. To create a Free Starter Workspace navigate to <tt>Start</tt> using the left nav. You can also use your existing Standard or Premium workspace with this Notebook.</p>
#     </div>
# </div>

# %% [markdown]
# # SingleStore Database Cheat Sheet
#
# List of useful commands for SingleStore SQL and Kai (MongoDB API) operations

# %% [markdown]
# ## Important Notes
#
# ### SingleStore Core Concepts
# 1. Reference tables don't need a SHARD KEY as they are replicated to all nodes
# 2. SingleStore supports both rowstore and columnstore (default) table types
# 3. Hash indexes are recommended for fast equality lookups on large tables
# 4. JSON operations are optimized for performance in SingleStore
# 5. Use Reference tables for lookup data that needs to be available on all nodes
#
# ### Vector Operations Tips
# 1. Vector dimensions must be specified at table creation
# 2. Normalize vectors to length 1 before inserting them in the database when you are doing cosine similarity calculations (but note that many models produce length-1 vectors so this is often not necessary; check the documentation for your model)
# 3. Choose appropriate index metric based on your use case
# 4. Vector operations support AI/ML workloads
# 5. Combine with full-text search for hybrid search capabilities
# 6. Available both in SQL and through SingleStore Kai (MongoDB API)
#
# ---
#
# *For the most up-to-date information, refer to the official SingleStore documentation at https://singlestore.com/docs.*

# %% [markdown]
# ## Database Operations

# %%
# %%sql
# # Show Databases
# SHOW DATABASES;
# Out:
# 10 rows affected.
# +-----------------------------+
# |           Database          |
# +-----------------------------+
# |           cluster           |
# | confluent_cloud_integration |
# |          dbTraining         |
# |       embeddings_demo       |
# |         godaddy_demo        |
# |      information_schema     |
# |           martech           |
# |            memsql           |
# |          sk_syntax          |
# |            telco            |
# +-----------------------------+

# %%
# %%sql
# # Create Database
# CREATE DATABASE database_name; # Note this will not work on free tier due to one DB constraint
# Out:
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Use Database
# USE database_name;
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Drop Database
# DROP DATABASE database_name; # Use with extreme caution
# Out:
# 6 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## Table Operations

# %%
# %%sql
# # Create Distributed Table
# CREATE TABLE posts (
#     id BIGINT AUTO_INCREMENT PRIMARY KEY,
#     title VARCHAR(255),
#     body TEXT,
#     category VARCHAR(50),
#     created_at DATETIME DEFAULT CURRENT_TIMESTAMP,
#     SHARD KEY (id)
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Create Reference Table
# CREATE REFERENCE TABLE categories (
#     id INT PRIMARY KEY,
#     name VARCHAR(50)
#     # No SHARD KEY needed for reference tables
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Create Columnstore Table
# CREATE TABLE analytics (
#     id BIGINT,
#     event_type VARCHAR(50),
#     ts DATETIME,
#     data JSON,
#     SORT KEY (ts),
#     SHARD KEY (id)
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Table Management

# %%
# %%sql
# # Show tables
# SHOW TABLES;
# Out:
# 3 rows affected.
# +-------------------------+
# | Tables_in_database_name |
# +-------------------------+
# |        analytics        |
# |        categories       |
# |          posts          |
# +-------------------------+

# %%
# %%sql
# # Describe table
# DESCRIBE posts;
# Out:
# 5 rows affected.
# +------------+--------------+------+-----+-------------------+----------------+
# |   Field    |     Type     | Null | Key |      Default      |     Extra      |
# +------------+--------------+------+-----+-------------------+----------------+
# |     id     |  bigint(20)  |  NO  | PRI |        None       | auto_increment |
# |   title    | varchar(255) | YES  |     |        None       |                |
# |    body    |     text     | YES  |     |        None       |                |
# |  category  | varchar(50)  | YES  |     |        None       |                |
# | created_at |   datetime   | YES  |     | CURRENT_TIMESTAMP |                |
# +------------+--------------+------+-----+-------------------+----------------+

# %%
# %%sql
# # Drop table
# DROP TABLE posts;
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## Data Manipulation

# %%
# %%sql
# # Insert single row
# INSERT INTO posts (title, body, category)
# VALUES ('Post One', 'Body of post one', 'News');
#
# # Insert multiple rows
# INSERT INTO posts (title, body, category) VALUES
#     ('Post Two', 'Body of post two', 'Technology'),
#     ('Post Three', 'Body of post three', 'News');
# Out:
# 1 rows affected.
# 2 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Select Data
# # Select all rows
# SELECT * FROM posts;
# Out:
# 3 rows affected.
# +------------------+------------+--------------------+------------+---------------------+
# |        id        |   title    |        body        |  category  |      created_at     |
# +------------------+------------+--------------------+------------+---------------------+
# | 4503599627370499 | Post Three | Body of post three |    News    | 2026-09-16 21:12:39 |
# | 4503599627370497 |  Post One  |  Body of post one  |    News    | 2026-09-16 21:12:39 |
# | 4503599627370498 |  Post Two  |  Body of post two  | Technology | 2026-09-16 21:12:39 |
# +------------------+------------+--------------------+------------+---------------------+

# %%
# %%sql
# # Select specific columns
# SELECT title, category FROM posts;
# Out:
# 3 rows affected.
# +------------+------------+
# |   title    |  category  |
# +------------+------------+
# | Post Three |    News    |
# |  Post One  |    News    |
# |  Post Two  | Technology |
# +------------+------------+

# %%
# %%sql
# # Select with condition
# SELECT * FROM posts WHERE category = 'News';
# Out:
# 2 rows affected.
# +------------------+------------+--------------------+----------+---------------------+
# |        id        |   title    |        body        | category |      created_at     |
# +------------------+------------+--------------------+----------+---------------------+
# | 4503599627370499 | Post Three | Body of post three |   News   | 2026-09-16 21:12:39 |
# | 4503599627370497 |  Post One  |  Body of post one  |   News   | 2026-09-16 21:12:39 |
# +------------------+------------+--------------------+----------+---------------------+

# %%
# %%sql
# # Update Data
# UPDATE posts
# SET body = 'Updated body'
# WHERE title = 'Post One';
# Out:
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Delete Data
# DELETE FROM posts WHERE title = 'Post One';
# Out:
# 1 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b class="fa fa-solid fa-exclamation-circle"></b>
#     <div>
#         <p><b>Action Required</b></p>
#         <p>Before running the pipeline examples below, be sure to select your database from the drop-down list at the top of this notebook. This updates the <tt>connection_url</tt> which is used by the <tt>%%sql</tt> magic command to connect to the selected database.</p>
#     </div>
# </div>

# %% [markdown]
# ## SingleStore Pipelines

# %% [markdown]
# Pipelines are used to bring data into SingleStore tables from different sources, for example an S3 bucket

# %% [markdown]
# ### Create Pipeline

# %%
# %%sql
# # Create the destination table for the S3 sample data.
# CREATE TABLE SalesData (
#     Date TEXT COLLATE utf8mb4_bin,
#     Store_ID BIGINT DEFAULT NULL,
#     ProductID TEXT COLLATE utf8mb4_bin,
#     Product_Name TEXT COLLATE utf8mb4_bin,
#     Product_Category TEXT COLLATE utf8mb4_bin,
#     Quantity_Sold BIGINT DEFAULT NULL,
#     Price FLOAT DEFAULT NULL,
#     Total_Sales FLOAT DEFAULT NULL
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Create Pipeline
# CREATE PIPELINE SalesData_Pipeline AS
# LOAD DATA S3 's3://singlestoreloaddata/SalesData/*.csv'
# CONFIG '{ "region": "ap-south-1" }'
# INTO TABLE SalesData
# FIELDS TERMINATED BY ','
# LINES TERMINATED BY '\n'
# IGNORE 1 lines;
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Start Pipeline

# %%
# %%sql
# START PIPELINE SalesData_Pipeline;
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Check pipeline status

# %%
# %%sql
# SELECT * FROM information_schema.pipelines_files
# WHERE pipeline_name = "SalesData_Pipeline";
# Out:
# 21 rows affected.
# +---------------+--------------------+-------------+----------------------------+-------------+------------+
# | DATABASE_NAME |   PIPELINE_NAME    | SOURCE_TYPE |         FILE_NAME          |  FILE_SIZE  | FILE_STATE |
# +---------------+--------------------+-------------+----------------------------+-------------+------------+
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_1.csv  |  43544209.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_10.csv |  43543437.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_11.csv |  43541193.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_12.csv |  43541894.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_13.csv |  43544837.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_14.csv |  43541462.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_15.csv |  43538815.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_16.csv |  43536237.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_17.csv |  43548982.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_18.csv |  43547556.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_19.csv |  43541455.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_2.csv  |  43552944.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_20.csv |  43545021.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_3.csv  |  43535512.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_4.csv  |  43546284.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_5.csv  |  43536967.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_6.csv  |  43540964.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_7.csv  |  43534930.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_8.csv  |  43539759.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     | SalesData/salesData_9.csv  |  43542785.0 |  Unloaded  |
# | database_name | SalesData_Pipeline |      S3     |  SalesData/sales_data.csv  | 885843591.0 |  Unloaded  |
# +---------------+--------------------+-------------+----------------------------+-------------+------------+

# %% [markdown]
# ### Stop pipeline

# %%
# %%sql
# STOP PIPELINE IF RUNNING SalesData_Pipeline;
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Drop Pipeline

# %%
# %%sql
# DROP PIPELINE IF EXISTS SalesData_Pipeline;
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## SingleStore Specific Features

# %% [markdown]
# ### JSON Operations

# %%
# %%sql
# # Create table with JSON column
# CREATE TABLE json_posts (
#     id BIGINT AUTO_INCREMENT PRIMARY KEY,
#     data JSON,
#     SHARD KEY (id)
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Insert JSON
# INSERT INTO json_posts (data)
# VALUES ('{"title": "Post One", "tags": ["news", "events"]}');
# Out:
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT JSON_EXTRACT_STRING(data, 'title') AS title
# FROM json_posts;
# Out:
# 1 rows affected.
# +----------+
# |  title   |
# +----------+
# | Post One |
# +----------+

# %% [markdown]
# ### Vector Operations

# %%
# %%sql
# # Create table with vector column
# CREATE TABLE embeddings (
#     id BIGINT AUTO_INCREMENT PRIMARY KEY,
#     description TEXT,
#     embedding VECTOR(1536),  -- Specify vector dimension
#     SHARD KEY (id)
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Create vector index using dot product as distance metric
# ALTER TABLE embeddings ADD VECTOR INDEX idx_embedding (embedding)
# INDEX_OPTIONS '{"metric_type": "DOT_PRODUCT"}';
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Generate three valid 1,536-dimensional test vectors.
# SET @v1 = CONCAT('[1,', RPAD('0,', 3068, '0,'), '0]');
# SET @v2 = CONCAT('[0,1,', RPAD('0,', 3066, '0,'), '0]');
# SET @v3 = CONCAT('[', RPAD('0,', 3070, '0,'), '1]');
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Confirm that each test vector contains exactly 1,536 dimensions.
# SELECT JSON_LENGTH(@v1) AS v1_dimensions,
#        JSON_LENGTH(@v2) AS v2_dimensions,
#        JSON_LENGTH(@v3) AS v3_dimensions;
# Out:
# 1 rows affected.
# +---------------+---------------+---------------+
# | v1_dimensions | v2_dimensions | v3_dimensions |
# +---------------+---------------+---------------+
# |      1536     |      1536     |      1536     |
# +---------------+---------------+---------------+

# %%
# %%sql
# # Remove prior test rows so the example can be rerun cleanly.
# DELETE FROM embeddings
# WHERE id IN (1, 2, 3);
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Insert sample descriptions and their corresponding test vectors.
# INSERT INTO embeddings (id, description, embedding)
# VALUES
# (1, 'Vector search for product recommendations', @v1),
# (2, 'Full-text search for product descriptions', @v2),
# (3, 'Hybrid search combining vector and text search', @v3);
# Out:
# 3 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# # Rank rows by similarity to the first test vector.
# SELECT id, description,
#        DOT_PRODUCT(embedding, @v1) AS similarity
# FROM embeddings
# ORDER BY similarity DESC
# LIMIT 10;
# Out:
# 3 rows affected.
# +----+------------------------------------------------+------------+
# | id |                  description                   | similarity |
# +----+------------------------------------------------+------------+
# | 1  |   Vector search for product recommendations    |    1.0     |
# | 2  |   Full-text search for product descriptions    |    0.0     |
# | 3  | Hybrid search combining vector and text search |    0.0     |
# +----+------------------------------------------------+------------+

# %% [markdown]
# ## SingleStore Kai (MongoDB API)
#
# ### MongoDB Client Connection
# ```
# mongodb://username:password@hostname:27017/database
# ```
#
# To run these commands:
#
# 1. Open **Editor → Open Kai Shell**.
# 2. Select a Kai-enabled cluster.
# 3. Run the commands directly in Kai Shell.
#
# Kai Shell connects automatically, so no connection string or credentials are required.
#
# ```javascript
# show dbs
# use mydb
# show collections
# db.createCollection("users")
# show collections
# ```

# %% [markdown]
# <div id="singlestore-footer" style="background-color: rgba(194, 193, 199, 0.25); height:2px; margin-bottom:10px"></div>
# <div><img src="https://raw.githubusercontent.com/singlestore-labs/spaces-notebooks/master/common/images/singlestore-logo-grey.png" style="padding: 0px; margin: 0px; height: 24px"/></div>
